# %%
import requests
import json

API_KEY = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..kwCtqfz11K5FbbAPMS7ikSeFc5rHHiQZBR6sEZVCrerei5CxsMc-l5o74kwieChKuhbW_0VqO_Kh2Wf503sZpQ"
BASE_URL = "https://api.clashofclans.com/v1"

def get_player_data(player_tag):
    headers = {"Authorization": f"Bearer {API_KEY}"}
    url = f"{BASE_URL}/players/%23{player_tag.strip('#')}"
    response = requests.get(url, headers=headers)
    
    if response.status_code == 200:
        return response.json()
    else:
        print("Error:", response.json())
        return None

if __name__ == "__main__":
    player_tag = "#P0Q8LQ0QJ"
    data = get_player_data(player_tag)
    print(json.dumps(data, indent=4))
# Out:
# {
#     "tag": "#P0Q8LQ0QJ",
#     "name": "sandeep",
#     "townHallLevel": 13,
#     "townHallWeaponLevel": 5,
#     "expLevel": 169,
#     "trophies": 2694,
#     "bestTrophies": 3275,
#     "warStars": 1163,
#     "attackWins": 0,
#     "defenseWins": 0,
#     "builderHallLevel": 8,
#     "builderBaseTrophies": 2562,
#     "bestBuilderBaseTrophies": 2649,
#     "role": "admin",
#     "warPreference": "in",
#     "donations": 0,
#     "donationsReceived": 154,
#     "clanCapitalContributions": 49420,
#     "clan": {
#         "tag": "#29YCYJRJU",
#         "name": "SPOILS OF WAR",
#         "clanLevel": 12,
#         "badgeUrls": {
#             "small": "https://api-assets.clashofclans.com/badges/70/w3BBPAU9FxAskYeyVE4UO7RQgJ2FuyXb8nBoNuQdnwU.png",
#             "large": "https://api-assets.clashofclans.com/badges/512/w3BBPAU9FxAskYeyVE4UO7RQgJ2FuyXb8nBoNuQdnwU.png",
# ...
